# %% [markdown]
# # V12: KI richtig fragen — Prompt Engineering 💬
#
# **Lernziele:**
# 1. Die 3 Bausteine eines guten Prompts kennen
# 2. Schlechte Prompts verbessern können
# 3. f-Strings sicher einsetzen
#
# **Punkte:** 🔄 Warm-Up (1) | 🐍 Übung (2) | 🏆 Challenge (3) | 🌟 Bonus (5)

# %% [markdown]
# ---
# ## 🔄 Warm-Up: f-Strings auffrischen (1 Punkt)
#
# Führe aus und ändere dann die Werte!

# %%
# Warm-Up: f-Strings
maschine = "CNC-Fräse 01"
status = "läuft"
temperatur = 42

print(f"Maschine '{maschine}' — Status: {status}, Temperatur: {temperatur}°C")

# TODO: Ändere die 3 Variablen oben zu deinen eigenen Werten und führe nochmal aus!

# %% [markdown]
# ---
# ## 📖 Die 3 Bausteine eines guten Prompts
#
# ```
# Guter Prompt = Kontext + Aufgabe + Format
# ```
#
# | Baustein | Frage | Beispiel |
# |----------|-------|----------|
# | **Kontext** | Wer bist du? | "Maschinenbau-Student, 1. Semester" |
# | **Aufgabe** | Was soll die KI tun? | "Erkläre Vorschubgeschwindigkeit" |
# | **Format** | Wie soll die Antwort sein? | "3 Sätze, einfache Sprache" |

# %% [markdown]
# ### Wir bauen Prompt-Templates mit Python!

# %%
# Demo: Prompt aus Bausteinen zusammenbauen
kontext = "Maschinenbau-Student, 1. Semester"
aufgabe = "Erkläre den Begriff Vorschubgeschwindigkeit"
format_wunsch = "Maximal 3 Sätze, einfache Sprache"

prompt = f"""Kontext: {kontext}
Aufgabe: {aufgabe}
Format: {format_wunsch}"""

print("=== Generierter Prompt ===")
print(prompt)
print()
print("Diesen Prompt könntest du jetzt bei ChatGPT eingeben! 🚀")

# %% [markdown]
# ---
# ## 🐍 Geführte Übung: Prompt-Generator (2 Punkte)
#
# ### Schritt 1: Bausteine abfragen

# %%
# Schritt 1: Drei Bausteine vom Benutzer abfragen
print("=== Prompt-Generator ===")
print()

kontext = input("Kontext (Wer bist du?): ")
aufgabe = input("Aufgabe (Was soll die KI tun?): ")
format_wunsch = input("Format (Wie soll die Antwort sein?): ")

print()
print("Eingaben gespeichert! ✅")

# %% [markdown]
# ### Schritt 2: Prompt zusammenbauen
#
# **Deine Aufgabe:** Ergänze die `___` Lücken!

# %%
# Schritt 2: Prompt zusammenbauen und ausgeben
print("--- Dein fertiger Prompt ---")
print()
print(f"Kontext: {___}")      # TODO: Welche Variable?
print(f"Aufgabe: {___}")      # TODO: Welche Variable?
print(f"Format: {___}")       # TODO: Welche Variable?
print()
print("Kopiere diesen Prompt und teste ihn bei ChatGPT! 🚀")

# %% [markdown]
# ---
# ## 📖 Vorher/Nachher: Prompts verbessern
#
# Schau dir an, wie man einen Prompt verbessern kann:

# %%
# Vorher vs. Nachher
schlecht = "Erkläre Stahl."
gut = """Kontext: Maschinenbau-Student, 1. Semester.
Aufgabe: Erkläre, was Stahl ist und warum er im Maschinenbau wichtig ist.
Format: 3 Sätze, einfache Sprache, ein Alltagsbeispiel."""

print("❌ Schlechter Prompt:")
print(schlecht)
print()
print("✅ Guter Prompt:")
print(gut)

# %% [markdown]
# ---
# ## 🏆 Challenge: Fachbegriff-Übersetzer (3 Punkte)
#
# Baue ein Programm, das technische Fachbegriffe in einfache Sprache übersetzt.
#
# **Deine Aufgabe:** Ergänze mindestens **2 weitere Begriffe**!

# %%
# 🏆 Challenge: Fachbegriff-Übersetzer

print("=== Fachbegriff-Übersetzer ===")
begriff = input("Technischer Begriff: ")

if begriff == "Spindeldrehzahl":
    print("→ Wie schnell sich das Werkzeug dreht (Umdrehungen pro Minute)")
elif begriff == "Vorschubgeschwindigkeit":
    print("→ Wie schnell sich das Werkstück bewegt (mm pro Minute)")
elif begriff == "Kühlschmierstoff":
    print("→ Flüssigkeit die beim Fräsen kühlt und schmiert")
# TODO: Füge mindestens 2 weitere elif-Blöcke hinzu!
# elif begriff == "???":
#     print("→ ???")
else:
    print(f"→ '{begriff}' kenne ich noch nicht!")

# %% [markdown]
# ---
# ## 🌟 Bonus: Groß-/Kleinschreibung ignorieren (5 Punkte)
#
# Problem: Wenn der Benutzer `"spindeldrehzahl"` (klein) eingibt, findet das Programm es nicht!
#
# **Tipp:** Verwende `.lower()` um die Eingabe in Kleinbuchstaben umzuwandeln.

# %%
# 🌟 Bonus: Groß-/Kleinschreibung egal machen

print("=== Fachbegriff-Übersetzer (verbessert) ===")
eingabe = input("Technischer Begriff: ")
begriff = eingabe.lower()     # Alles in Kleinbuchstaben!

# TODO: Passe die Vergleiche an (alles klein schreiben!)
if begriff == "spindeldrehzahl":
    print("→ Wie schnell sich das Werkzeug dreht")
elif ___:     # TODO: Ergänze
    print("→ Wie schnell sich das Werkstück bewegt")
else:
    print(f"→ '{eingabe}' kenne ich noch nicht!")

# %% [markdown]
# ---
# ## 📊 Punkte-Übersicht
#
# | Aufgabe | Punkte | Geschafft? |
# |---------|--------|------------|
# | 🔄 Warm-Up (f-Strings) | 1 | |
# | 🐍 Prompt-Generator | 2 | |
# | 🏆 Fachbegriff-Übersetzer | 3 | |
# | 🌟 Bonus (lower) | 5 | |
# | **Gesamt** | **max. 11** | |
#
# ---
# *V12 — KI richtig fragen: Prompt Engineering*
